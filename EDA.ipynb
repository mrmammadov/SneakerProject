# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv(r'C:\Users\z0044zfu\Desktop\Topic 7\postings.csv', nrows=10000)

# %%
data.head()
# Out:
#    Unnamed: 0        id    typename shortcode caption  first_comment    text  \
# 0           0  76939462  GraphImage     ElgDG     Run            NaN     Run
# 1           1  76939718  GraphImage     ElgHG     Run            NaN     Run
# 2           2  76940738  GraphImage     ElgXC  Baller            NaN  Baller
# 3           3  76951807  GraphImage     EljD_  Bletel            NaN  Bletel
# 4           4  78399988  GraphImage     ErEn0   Penny            NaN   Penny
#
#    comments_disabled                    taken_at  dimension_x  dimension_y  \
# 0                  0  2011-05-22 20:10:09.000000          612          612
# 1                  0  2011-05-22 20:10:32.000000          612          612
# 2                  0  2011-05-22 20:12:12.000000          612          612
# 3                  0  2011-05-22 20:28:44.000000          612          612
# 4                  0  2011-05-24 22:19:35.000000          612          612
#
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'id', 'typename', 'shortcode', 'caption', 'first_comment',
#        'text', 'comments_disabled', 'taken_at', 'dimension_x', 'dimension_y',
#        'owner_id', 'owner_username', 'owner_follower_count', 'is_video',
#        'caption_is_edited', 'has_ranked_comments', 'is_ad', 'like_count',
#        'comment_count', 'location_id', 'location_name', 'location_lat',
#        'location_lon', 'created_at', 'accessibility_caption',
#        'real_like_count'],
#       dtype='object')

# %%
data.first_comment.isna().sum()
# Out:
# 10000

# %%
data.text
# Out:
# 0                      Run
# 1                      Run
# 2                   Baller
# 3                   Bletel
# 4                    Penny
#               ...
# 995          Loveeeeeeee 😍
# 996                    NaN
# 997                    Hy😄
# 998            Boyfriend 💙
# 999    Boyfriend's B'Day 😚
# Name: text, Length: 1000, dtype: object

# %%
data.caption
# Out:
# 0                      Run
# 1                      Run
# 2                   Baller
# 3                   Bletel
# 4                    Penny
#               ...
# 995          Loveeeeeeee 😍
# 996                    NaN
# 997                    Hy😄
# 998            Boyfriend 💙
# 999    Boyfriend's B'Day 😚
# Name: caption, Length: 1000, dtype: object

# %%
caption_vs_text = data[data.caption != data.text]

# %%
caption_vs_text
# Out:
#      Unnamed: 0         id    typename shortcode caption  first_comment text  \
# 6             6   82243711  GraphImage     E5vB_     NaN            NaN  NaN
# 7             7  108523909  GraphImage     Gd_GF     NaN            NaN  NaN
# 8             8  109232246  GraphImage     GgsB2     NaN            NaN  NaN
# 11           11  130544320  GraphImage     Hx_LA     NaN            NaN  NaN
# 16           16  142774699  GraphImage     IgpGr     NaN            NaN  NaN
# ..          ...        ...         ...       ...     ...            ...  ...
# 973         973  580397171  GraphImage     imChz     NaN            NaN  NaN
# 977         977  581794316  GraphImage     irXoM     NaN            NaN  NaN
# 982         982  586184481  GraphImage     i8Hch     NaN            NaN  NaN
# 988         988  597689393  GraphImage     joAQx     NaN            NaN  NaN
# 996         996  608559108  GraphImage     kReAE     NaN            NaN  NaN
#
# ...

# %%
data.caption.isna().sum()
# Out:
# 203

# %%
caption_vs_text.caption.value_counts()
# Out:
# Bentley enjoying Monkey. Ignoring the football game as usual.                                   1
# Moroccan Dyembe                                                                                 1
# Route 66                                                                                        1
# Cold Evan                                                                                       1
# #Nike wearing some air max's 1's for thanksgiving FOOTBALL!                                     1
# Old pic. Couple summers ago. One hell of a weekend on a clients dime!!!! #dreamcar #Porsche     1
# An hour before his dinner time this starts.                                                     1
# @sneakerpedia wearing ACG's today. Laces for @misterqmart & @tdotloveskicks                     1
# Latest pickups....                                                                              1
# @vashe or these?                                                                                1
# ...

# %%
caption_vs_text.text.value_counts()
# Out:
# Izan Navideño 🎅! Feliz Navidad y un prospero año nuevo a todos!\n#snapseed #iphone3gs #navidad #valencia #iphoneonly #iphonesia #instagram #popular #picoftheday #fotodeldia #igersmadrid #instagrameando #instagrameandofeat #instagramers #iphoneography #ig #instagood #instamood #jj #igers #madrid #lafotodeldia #ignation #webstagram #statigram #igdaily #instahub #instagramhub #instadaily                                            1
# Cold Evan\n#snapseed #iphone3gs #blackandwhite #bw #bwcontest #bwcontest2 #bnw #bwoftheday #mividaenblancoynegro #bwcolor #blancoynegro #iphoneonly #iphonesia #instagram #popular #picoftheday #fotodeldia #igersmadrid #instagrameando #instagrameandofeat #instagramers #iphoneography #ig #instagood #instamood #jj #igers #madrid #igdaily #instahub                                                                                      1
# ...

# %%
caption_vs_text.caption.iloc[1] == np.nan
# Out:
# False

# %%
caption_vs_text
# Out:
#      Unnamed: 0         id    typename shortcode caption  first_comment text  \
# 6             6   82243711  GraphImage     E5vB_     NaN            NaN  NaN
# 7             7  108523909  GraphImage     Gd_GF     NaN            NaN  NaN
# 8             8  109232246  GraphImage     GgsB2     NaN            NaN  NaN
# 11           11  130544320  GraphImage     Hx_LA     NaN            NaN  NaN
# 16           16  142774699  GraphImage     IgpGr     NaN            NaN  NaN
# ..          ...        ...         ...       ...     ...            ...  ...
# 973         973  580397171  GraphImage     imChz     NaN            NaN  NaN
# 977         977  581794316  GraphImage     irXoM     NaN            NaN  NaN
# 982         982  586184481  GraphImage     i8Hch     NaN            NaN  NaN
# 988         988  597689393  GraphImage     joAQx     NaN            NaN  NaN
# 996         996  608559108  GraphImage     kReAE     NaN            NaN  NaN
#
# ...

# %%
data.head(10)
# Out:
#    Unnamed: 0         id    typename shortcode     caption  first_comment  \
# 0           0   76939462  GraphImage     ElgDG         Run            NaN
# 1           1   76939718  GraphImage     ElgHG         Run            NaN
# 2           2   76940738  GraphImage     ElgXC      Baller            NaN
# 3           3   76951807  GraphImage     EljD_      Bletel            NaN
# 4           4   78399988  GraphImage     ErEn0       Penny            NaN
# 5           5   78441609  GraphImage     ErOyJ       Decks            NaN
# 6           6   82243711  GraphImage     E5vB_         NaN            NaN
# 7           7  108523909  GraphImage     Gd_GF         NaN            NaN
# 8           8  109232246  GraphImage     GgsB2         NaN            NaN
# 9           9  120684023  GraphImage     HMX33  Melonville            NaN
#
#          text  comments_disabled                    taken_at  dimension_x  \
# 0         Run                  0  2011-05-22 20:10:09.000000          612
# ...
